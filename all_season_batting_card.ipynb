# %%
import pandas as pd 
import numpy as np
import matplotlib as plt 
import seaborn as sea

# %%
df= pd.read_csv(r"all_season_batting_card.csv",encoding='unicode_escape')

# %%
df.shape
# Out:
# (15720, 25)

# %%
df
# Out:
#        season  match_id match_name home_team away_team  \
# 0      2023.0   1359475   GT v CSK        GT       CSK
# 1      2023.0   1359475   GT v CSK        GT       CSK
# 2      2023.0   1359475   GT v CSK        GT       CSK
# 3      2023.0   1359475   GT v CSK        GT       CSK
# 4      2023.0   1359475   GT v CSK        GT       CSK
# ...       ...       ...        ...       ...       ...
# 15715  2008.0    336040   CSK v RR       CSK        RR
# 15716  2008.0    336040   CSK v RR       CSK        RR
# 15717  2008.0    336040   CSK v RR       CSK        RR
# 15718  2008.0    336040   CSK v RR       CSK        RR
# 15719  2008.0    336040   CSK v RR       CSK        RR
#
#                                           venue       city country  \
# 0      Narendra Modi Stadium, Motera, Ahmedabad  Ahmedabad   India
# 1      Narendra Modi Stadium, Motera, Ahmedabad  Ahmedabad   India
# 2      Narendra Modi Stadium, Motera, Ahmedabad  Ahmedabad   India
# ...

# %%
df = df.rename(columns={
    'fullName': 'Full_Name',
    'ballsFaced': 'Balls_Faced',
    'strikeRate': 'Strike_Rate',
    'isNotOut': 'Is_Not_Out',
    'runningScore': 'Running_Score',
    'runningOver': 'Running_Over'
})

# %%
df.head()
# Out:
#    season  match_id match_name home_team away_team  \
# 0  2023.0   1359475   GT v CSK        GT       CSK
# 1  2023.0   1359475   GT v CSK        GT       CSK
# 2  2023.0   1359475   GT v CSK        GT       CSK
# 3  2023.0   1359475   GT v CSK        GT       CSK
# 4  2023.0   1359475   GT v CSK        GT       CSK
#
#                                       venue       city country  \
# 0  Narendra Modi Stadium, Motera, Ahmedabad  Ahmedabad   India
# 1  Narendra Modi Stadium, Motera, Ahmedabad  Ahmedabad   India
# 2  Narendra Modi Stadium, Motera, Ahmedabad  Ahmedabad   India
# 3  Narendra Modi Stadium, Motera, Ahmedabad  Ahmedabad   India
# 4  Narendra Modi Stadium, Motera, Ahmedabad  Ahmedabad   India
#
#   current_innings  innings_id  ... fours sixes  Strike_Rate  captain  \
# 0             CSK           1  ...   0.0   0.0        16.66    False
# 1             CSK           1  ...   4.0   9.0       184.00    False
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of        season  match_id match_name home_team away_team  \
# 0      2023.0   1359475   GT v CSK        GT       CSK
# 1      2023.0   1359475   GT v CSK        GT       CSK
# 2      2023.0   1359475   GT v CSK        GT       CSK
# 3      2023.0   1359475   GT v CSK        GT       CSK
# 4      2023.0   1359475   GT v CSK        GT       CSK
# ...       ...       ...        ...       ...       ...
# 15715  2008.0    336040   CSK v RR       CSK        RR
# 15716  2008.0    336040   CSK v RR       CSK        RR
# 15717  2008.0    336040   CSK v RR       CSK        RR
# 15718  2008.0    336040   CSK v RR       CSK        RR
# 15719  2008.0    336040   CSK v RR       CSK        RR
#
#                                           venue       city country  \
# 0      Narendra Modi Stadium, Motera, Ahmedabad  Ahmedabad   India
# 1      Narendra Modi Stadium, Motera, Ahmedabad  Ahmedabad   India
# 2      Narendra Modi Stadium, Motera, Ahmedabad  Ahmedabad   India
# ...

# %%
df.isnull().any()
# Out:
# season              True
# match_id           False
# match_name         False
# home_team          False
# away_team          False
# venue              False
# city               False
# country            False
# current_innings    False
# innings_id         False
# name               False
# Full_Name          False
# runs                True
# Balls_Faced         True
# minutes             True
# fours               True
# sixes               True
# Strike_Rate         True
# captain            False
# Is_Not_Out          True
# Running_Score       True
# Running_Over        True
# shortText          False
# commentary          True
# link                True
# dtype: bool

# %%
df[df['runs'].isna()==1]
# Out:
#        season  match_id match_name home_team away_team  \
# 4219   2019.0   1175358    MI v DC        MI        DC
# 8823   2014.0    729293   CSK v DC       CSK        DC
# 10671  2013.0    598066  KXIP v MI      KXIP        MI
# 13123  2010.0    419114    DC v MI        DC        MI
# 14166  2009.0    392197   KKR v MI       KKR        MI
# 14249  2009.0    392202   CSK v RR       CSK        RR
#
#                                                    venue            city  \
# 4219                            Wankhede Stadium, Mumbai          Mumbai
# 8823                     Sheikh Zayed Stadium, Abu Dhabi       Abu Dhabi
# 10671  Himachal Pradesh Cricket Association Stadium, ...      Dharamsala
# 13123                        Arun Jaitley Stadium, Delhi           Delhi
# 14166                   St George's Park, Port Elizabeth  Port Elizabeth
# 14249                         SuperSport Park, Centurion       Centurion
#
# ...

# %%
df['runs']=df['runs'].fillna(0)
df['runs']
# Out:
# 0         1.0
# 1        92.0
# 2        23.0
# 3         7.0
# 4        12.0
#          ...
# 15715    56.0
# 15716    12.0
# 15717     0.0
# 15718     9.0
# 15719     9.0
# Name: runs, Length: 15720, dtype: float64

# %%
df['Balls_Faced']=df['Balls_Faced'].fillna(0)
df['Balls_Faced']
# Out:
# 0         6.0
# 1        50.0
# 2        17.0
# 3         6.0
# 4        12.0
#          ...
# 15715    39.0
# 15716     9.0
# 15717     1.0
# 15718     9.0
# 15719     7.0
# Name: Balls_Faced, Length: 15720, dtype: float64

# %%
df.isnull().any()
# Out:
# season              True
# match_id           False
# match_name         False
# home_team          False
# away_team          False
# venue              False
# city               False
# country            False
# current_innings    False
# innings_id         False
# name               False
# Full_Name          False
# runs               False
# Balls_Faced        False
# minutes             True
# fours               True
# sixes               True
# Strike_Rate         True
# captain            False
# Is_Not_Out          True
# Running_Score       True
# Running_Over        True
# shortText          False
# commentary          True
# link                True
# dtype: bool

# %%
df['minutes']=df['minutes'].fillna(0)
df['runs']=df['runs'].fillna(0)
df['fours']=df['fours'].fillna(0)
df['sixes']=df['sixes'].fillna(0)
df['Strike_Rate']=df['Strike_Rate'].fillna(0)
df['Is_Not_Out']=df['Is_Not_Out'].fillna(0)
df['Running_Score']=df['Running_Score'].fillna(0)
df['Running_Over']=df['Running_Over'].fillna(0)



df.isnull().any()
# Out:
# season              True
# match_id           False
# match_name         False
# home_team          False
# away_team          False
# venue              False
# city               False
# country            False
# current_innings    False
# innings_id         False
# name               False
# Full_Name          False
# runs               False
# Balls_Faced        False
# minutes            False
# fours              False
# sixes              False
# Strike_Rate        False
# captain            False
# Is_Not_Out         False
# Running_Score      False
# Running_Over       False
# shortText          False
# commentary          True
# link                True
# dtype: bool

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 15715    False
# 15716    False
# 15717    False
# 15718    False
# 15719    False
# Length: 15720, dtype: bool

# %%
df[df['Full_Name'].duplicated()==1]
# Out:
#        season  match_id match_name home_team away_team  \
# 81     2023.0   1359480  CSK v LSG       CSK       LSG
# 82     2023.0   1359480  CSK v LSG       CSK       LSG
# 83     2023.0   1359480  CSK v LSG       CSK       LSG
# 84     2023.0   1359480  CSK v LSG       CSK       LSG
# 85     2023.0   1359480  CSK v LSG       CSK       LSG
# ...       ...       ...        ...       ...       ...
# 15715  2008.0    336040   CSK v RR       CSK        RR
# 15716  2008.0    336040   CSK v RR       CSK        RR
# 15717  2008.0    336040   CSK v RR       CSK        RR
# 15718  2008.0    336040   CSK v RR       CSK        RR
# 15719  2008.0    336040   CSK v RR       CSK        RR
#
#                                           venue     city country  \
# 81     MA Chidambaram Stadium, Chepauk, Chennai  Chennai   India
# 82     MA Chidambaram Stadium, Chepauk, Chennai  Chennai   India
# 83     MA Chidambaram Stadium, Chepauk, Chennai  Chennai   India
# ...

# %%
df=df.drop_duplicates()

# %%
print(df)
# Out:
#        season  match_id match_name home_team away_team  \
# 0      2023.0   1359475   GT v CSK        GT       CSK
# 1      2023.0   1359475   GT v CSK        GT       CSK
# 2      2023.0   1359475   GT v CSK        GT       CSK
# 3      2023.0   1359475   GT v CSK        GT       CSK
# 4      2023.0   1359475   GT v CSK        GT       CSK
# ...       ...       ...        ...       ...       ...
# 15715  2008.0    336040   CSK v RR       CSK        RR
# 15716  2008.0    336040   CSK v RR       CSK        RR
# 15717  2008.0    336040   CSK v RR       CSK        RR
# 15718  2008.0    336040   CSK v RR       CSK        RR
# 15719  2008.0    336040   CSK v RR       CSK        RR
#
#                                           venue       city country  \
# 0      Narendra Modi Stadium, Motera, Ahmedabad  Ahmedabad   India
# 1      Narendra Modi Stadium, Motera, Ahmedabad  Ahmedabad   India
# 2      Narendra Modi Stadium, Motera, Ahmedabad  Ahmedabad   India
# ...

# %%
columns=['season']
df['season'] = df['season'].fillna(0)
df[columns]=df[columns].astype(int)

# %%
df.isnull().any()
# Out:
# season             False
# match_id           False
# match_name         False
# home_team          False
# away_team          False
# venue              False
# city               False
# country            False
# current_innings    False
# innings_id         False
# name               False
# Full_Name          False
# runs               False
# Balls_Faced        False
# minutes            False
# fours              False
# sixes              False
# Strike_Rate        False
# captain            False
# Is_Not_Out         False
# Running_Score      False
# Running_Over       False
# shortText          False
# commentary          True
# link                True
# dtype: bool

# %%
columns = ['commentary','link']
df.drop(columns=columns, inplace=True)

# %%
df.isnull().any()
# Out:
# season             False
# match_id           False
# match_name         False
# home_team          False
# away_team          False
# venue              False
# city               False
# country            False
# current_innings    False
# innings_id         False
# name               False
# Full_Name          False
# runs               False
# Balls_Faced        False
# minutes            False
# fours              False
# sixes              False
# Strike_Rate        False
# captain            False
# Is_Not_Out         False
# Running_Score      False
# Running_Over       False
# shortText          False
# dtype: bool

# %%
columns = ['shortText']
df.drop(columns=columns, inplace=True)

# %%
print(df)
# Out:
#        season  match_id match_name home_team away_team  \
# 0        2023   1359475   GT v CSK        GT       CSK
# 1        2023   1359475   GT v CSK        GT       CSK
# 2        2023   1359475   GT v CSK        GT       CSK
# 3        2023   1359475   GT v CSK        GT       CSK
# 4        2023   1359475   GT v CSK        GT       CSK
# ...       ...       ...        ...       ...       ...
# 15715    2008    336040   CSK v RR       CSK        RR
# 15716    2008    336040   CSK v RR       CSK        RR
# 15717    2008    336040   CSK v RR       CSK        RR
# 15718    2008    336040   CSK v RR       CSK        RR
# 15719    2008    336040   CSK v RR       CSK        RR
#
#                                           venue       city country  \
# 0      Narendra Modi Stadium, Motera, Ahmedabad  Ahmedabad   India
# 1      Narendra Modi Stadium, Motera, Ahmedabad  Ahmedabad   India
# 2      Narendra Modi Stadium, Motera, Ahmedabad  Ahmedabad   India
# ...

# %%
minutes_column = df['minutes']

print(minutes_column)
# Out:
# 0        -
# 1        -
# 2        -
# 3        -
# 4        -
#         ..
# 15715    -
# 15716    -
# 15717    -
# 15718    -
# 15719    -
# Name: minutes, Length: 15720, dtype: object

# %%
df['minutes']=df['minutes'].fillna(0)
print(df['minutes'])
# Out:
# 0        -
# 1        -
# 2        -
# 3        -
# 4        -
#         ..
# 15715    -
# 15716    -
# 15717    -
# 15718    -
# 15719    -
# Name: minutes, Length: 15720, dtype: object

# %%
df['minutes'].replace('-', np.NaN, inplace=True)  # Replacing empty strings with NaN
df['minutes'] = df['minutes'].fillna(0)  #  filling  NaNs with 0
print(df['minutes'])
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 15715    0
# 15716    0
# 15717    0
# 15718    0
# 15719    0
# Name: minutes, Length: 15720, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15720 entries, 0 to 15719
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   season           15720 non-null  int32
#  1   match_id         15720 non-null  int64
#  2   match_name       15720 non-null  object
#  3   home_team        15720 non-null  object
#  4   away_team        15720 non-null  object
#  5   venue            15720 non-null  object
#  6   city             15720 non-null  object
#  7   country          15720 non-null  object
#  8   current_innings  15720 non-null  object
#  9   innings_id       15720 non-null  int64
#  10  name             15720 non-null  object
#  11  Full_Name        15720 non-null  object
#  12  runs             15720 non-null  float64
#  13  Balls_Faced      15720 non-null  float64
#  14  minutes          15720 non-null  object
#  15  fours            15720 non-null  float64
# ...

# %%
columns=['match_name','home_team','away_team','venue','city','country','current_innings']
df.drop(columns,inplace=True,axis=1)

# %%
print(df)
# Out:
#        season  match_id  innings_id           name        Full_Name  runs  \
# 0        2023   1359475           1      DP Conway     Devon Conway   1.0
# 1        2023   1359475           1     RD Gaikwad  Ruturaj Gaikwad  92.0
# 2        2023   1359475           1         MM Ali        Moeen Ali  23.0
# 3        2023   1359475           1      BA Stokes       Ben Stokes   7.0
# 4        2023   1359475           1      AT Rayudu    Ambati Rayudu  12.0
# ...       ...       ...         ...            ...              ...   ...
# 15715    2008    336040           2      YK Pathan     Yusuf Pathan  56.0
# 15716    2008    336040           2         M Kaif    Mohammad Kaif  12.0
# 15717    2008    336040           2      RA Jadeja  Ravindra Jadeja   0.0
# 15718    2008    336040           2       SK Warne      Shane Warne   9.0
# 15719    2008    336040           2  Sohail Tanvir    Sohail Tanvir   9.0
#
#        Balls_Faced minutes  fours  sixes Strike_Rate  captain Is_Not_Out  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15720 entries, 0 to 15719
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   season         15720 non-null  int32
#  1   match_id       15720 non-null  int64
#  2   innings_id     15720 non-null  int64
#  3   name           15720 non-null  object
#  4   Full_Name      15720 non-null  object
#  5   runs           15720 non-null  float64
#  6   Balls_Faced    15720 non-null  float64
#  7   minutes        15720 non-null  object
#  8   fours          15720 non-null  float64
#  9   sixes          15720 non-null  float64
#  10  Strike_Rate    15720 non-null  object
#  11  captain        15720 non-null  bool
#  12  Is_Not_Out     15720 non-null  object
#  13  Running_Score  15720 non-null  object
#  14  Running_Over   15720 non-null  float64
# dtypes: bool(1), float64(5), int32(1), int64(2), object(6)
# memory usage: 1.8+ MB

# %%
columns=[ 'name','Full_Name']
df.drop(columns,inplace=True,axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15720 entries, 0 to 15719
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   season         15720 non-null  int32
#  1   match_id       15720 non-null  int64
#  2   innings_id     15720 non-null  int64
#  3   runs           15720 non-null  float64
#  4   Balls_Faced    15720 non-null  float64
#  5   minutes        15720 non-null  object
#  6   fours          15720 non-null  float64
#  7   sixes          15720 non-null  float64
#  8   Strike_Rate    15720 non-null  object
#  9   captain        15720 non-null  bool
#  10  Is_Not_Out     15720 non-null  object
#  11  Running_Score  15720 non-null  object
#  12  Running_Over   15720 non-null  float64
# dtypes: bool(1), float64(5), int32(1), int64(2), object(4)
# memory usage: 1.5+ MB

# %%
df['minutes'] = df['minutes'].astype(float).astype(int)

# %%
print(df['minutes'])
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 15715    0
# 15716    0
# 15717    0
# 15718    0
# 15719    0
# Name: minutes, Length: 15720, dtype: int32

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15720 entries, 0 to 15719
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   season         15720 non-null  int32
#  1   match_id       15720 non-null  int64
#  2   innings_id     15720 non-null  int64
#  3   runs           15720 non-null  float64
#  4   Balls_Faced    15720 non-null  float64
#  5   minutes        15720 non-null  int32
#  6   fours          15720 non-null  float64
#  7   sixes          15720 non-null  float64
#  8   Strike_Rate    15720 non-null  object
#  9   captain        15720 non-null  bool
#  10  Is_Not_Out     15720 non-null  object
#  11  Running_Score  15720 non-null  object
#  12  Running_Over   15720 non-null  float64
# dtypes: bool(1), float64(5), int32(2), int64(2), object(3)
# memory usage: 1.5+ MB

# %%
df['runs'] = df['runs'].astype(int)
df['Balls_Faced'] = df['Balls_Faced'].astype(int)
df['fours'] = df['fours'].astype(int)
df['sixes'] = df['sixes'].astype(int)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15720 entries, 0 to 15719
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   season         15720 non-null  int32
#  1   match_id       15720 non-null  int64
#  2   innings_id     15720 non-null  int64
#  3   runs           15720 non-null  int32
#  4   Balls_Faced    15720 non-null  int32
#  5   minutes        15720 non-null  int32
#  6   fours          15720 non-null  int32
#  7   sixes          15720 non-null  int32
#  8   Strike_Rate    15720 non-null  object
#  9   captain        15720 non-null  bool
#  10  Is_Not_Out     15720 non-null  object
#  11  Running_Score  15720 non-null  object
#  12  Running_Over   15720 non-null  float64
# dtypes: bool(1), float64(1), int32(6), int64(2), object(3)
# memory usage: 1.2+ MB

# %%
df['Strike_Rate'].replace('-',np.NaN,inplace=True)
df['Strike_Rate']=df['Strike_Rate'].fillna(0)
print(df['Strike_Rate'])
# Out:
# 0         16.66
# 1        184.00
# 2        135.29
# 3        116.66
# 4        100.00
#           ...
# 15715    143.58
# 15716    133.33
# 15717      0.00
# 15718    100.00
# 15719    128.57
# Name: Strike_Rate, Length: 15720, dtype: object

# %%
df['Strike_Rate']=df['Strike_Rate'].astype(float).astype(int)
df.info()
df['Is_Not_Out']=df['Is_Not_Out'].astype(bool)
df['Running_Over']=df['Running_Over'].astype(int)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15720 entries, 0 to 15719
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   season         15720 non-null  int32
#  1   match_id       15720 non-null  int64
#  2   innings_id     15720 non-null  int64
#  3   runs           15720 non-null  int32
#  4   Balls_Faced    15720 non-null  int32
#  5   minutes        15720 non-null  int32
#  6   fours          15720 non-null  int32
#  7   sixes          15720 non-null  int32
#  8   Strike_Rate    15720 non-null  int32
#  9   captain        15720 non-null  bool
#  10  Is_Not_Out     15720 non-null  object
#  11  Running_Score  15720 non-null  object
#  12  Running_Over   15720 non-null  float64
# dtypes: bool(1), float64(1), int32(7), int64(2), object(2)
# memory usage: 1.2+ MB

# %%
df.columns = df.columns.str.capitalize()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15720 entries, 0 to 15719
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Season         15720 non-null  int32
#  1   Match_id       15720 non-null  int64
#  2   Innings_id     15720 non-null  int64
#  3   Runs           15720 non-null  int32
#  4   Balls_faced    15720 non-null  int32
#  5   Minutes        15720 non-null  int32
#  6   Fours          15720 non-null  int32
#  7   Sixes          15720 non-null  int32
#  8   Strike_rate    15720 non-null  int32
#  9   Captain        15720 non-null  bool
#  10  Is_not_out     15720 non-null  bool
#  11  Running_score  15720 non-null  object
#  12  Running_over   15720 non-null  int32
# dtypes: bool(2), int32(8), int64(2), object(1)
# memory usage: 1013.2+ KB

# %%
df['Running_score'].str.split(pat = ':')
# Out:
# 0         [{'wickets',  1, 'runs',  14}]
# 1        [{'wickets',  5, 'runs',  151}]
# 2         [{'wickets',  2, 'runs',  50}]
# 3         [{'wickets',  3, 'runs',  70}]
# 4        [{'wickets',  4, 'runs',  121}]
#                       ...
# 15715    [{'wickets',  7, 'runs',  143}]
# 15716    [{'wickets',  5, 'runs',  139}]
# 15717    [{'wickets',  6, 'runs',  139}]
# 15718                               [{}]
# 15719                               [{}]
# Name: Running_score, Length: 15720, dtype: object

# %%
df['Running_score'].str.split(pat = ':').str[1]
# Out:
# 0         1, 'runs'
# 1         5, 'runs'
# 2         2, 'runs'
# 3         3, 'runs'
# 4         4, 'runs'
#             ...
# 15715     7, 'runs'
# 15716     5, 'runs'
# 15717     6, 'runs'
# 15718           NaN
# 15719           NaN
# Name: Running_score, Length: 15720, dtype: object

# %%
df['Running_score_Wickets']=df['Running_score'].str.split(pat = ':').str[1]

# %%
df['Running_score_Wickets'].str.split(pat=',').str[0]
# Out:
# 0          1
# 1          5
# 2          2
# 3          3
# 4          4
#         ...
# 15715      7
# 15716      5
# 15717      6
# 15718    NaN
# 15719    NaN
# Name: Running_score_Wickets, Length: 15720, dtype: object

# %%
df['Wickets_From_Running Score']=df['Running_score_Wickets'].str.split(pat=',').str[0]

# %%
df['Wickets_From_Running Score']
# Out:
# 0          1
# 1          5
# 2          2
# 3          3
# 4          4
#         ...
# 15715      7
# 15716      5
# 15717      6
# 15718    NaN
# 15719    NaN
# Name: Wickets_From_Running Score, Length: 15720, dtype: object

# %%
df['Running_score'].str.split(pat = ':').str[2]
# Out:
# 0          14}
# 1         151}
# 2          50}
# 3          70}
# 4         121}
#          ...
# 15715     143}
# 15716     139}
# 15717     139}
# 15718      NaN
# 15719      NaN
# Name: Running_score, Length: 15720, dtype: object

# %%
df['Running_score_Runs']=df['Running_score'].str.split(pat = ':').str[2]

# %%
df['Running_score_Runs'].str.split(pat='}').str[0]
# Out:
# 0          14
# 1         151
# 2          50
# 3          70
# 4         121
#          ...
# 15715     143
# 15716     139
# 15717     139
# 15718     NaN
# 15719     NaN
# Name: Running_score_Runs, Length: 15720, dtype: object

# %%
df['Runs_From_Running Score']=df['Running_score_Runs'].str.split(pat='}').str[0]

# %%
df['Runs_From_Running Score']
# Out:
# 0          14
# 1         151
# 2          50
# 3          70
# 4         121
#          ...
# 15715     143
# 15716     139
# 15717     139
# 15718     NaN
# 15719     NaN
# Name: Runs_From_Running Score, Length: 15720, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15720 entries, 0 to 15719
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Season                      15720 non-null  int32
#  1   Match_id                    15720 non-null  int64
#  2   Innings_id                  15720 non-null  int64
#  3   Runs                        15720 non-null  int32
#  4   Balls_faced                 15720 non-null  int32
#  5   Minutes                     15720 non-null  int32
#  6   Fours                       15720 non-null  int32
#  7   Sixes                       15720 non-null  int32
#  8   Strike_rate                 15720 non-null  int32
#  9   Captain                     15720 non-null  bool
#  10  Is_not_out                  15720 non-null  bool
#  11  Running_score               15720 non-null  object
#  12  Running_over                15720 non-null  int32
# ...

# %%
columns=[  'Running_score','Running_score_Wickets', 'Running_score_Runs' ]
df.drop(columns,inplace=True,axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15720 entries, 0 to 15719
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Season                      15720 non-null  int32
#  1   Match_id                    15720 non-null  int64
#  2   Innings_id                  15720 non-null  int64
#  3   Runs                        15720 non-null  int32
#  4   Balls_faced                 15720 non-null  int32
#  5   Minutes                     15720 non-null  int32
#  6   Fours                       15720 non-null  int32
#  7   Sixes                       15720 non-null  int32
#  8   Strike_rate                 15720 non-null  int32
#  9   Captain                     15720 non-null  bool
#  10  Is_not_out                  15720 non-null  bool
#  11  Running_over                15720 non-null  int32
#  12  Wickets_From_Running Score  12029 non-null  object
# ...

# %%
df['Wickets_From_Running Score']=df['Wickets_From_Running Score'].fillna(0)
df['Wickets_From_Running Score']
# Out:
# 0         1
# 1         5
# 2         2
# 3         3
# 4         4
#          ..
# 15715     7
# 15716     5
# 15717     6
# 15718     0
# 15719     0
# Name: Wickets_From_Running Score, Length: 15720, dtype: object

# %%
df['Runs_From_Running Score']
# Out:
# 0          14
# 1         151
# 2          50
# 3          70
# 4         121
#          ...
# 15715     143
# 15716     139
# 15717     139
# 15718     NaN
# 15719     NaN
# Name: Runs_From_Running Score, Length: 15720, dtype: object

# %%
df['Runs_From_Running Score']=df['Runs_From_Running Score'].fillna(0)
df['Runs_From_Running Score']
# Out:
# 0          14
# 1         151
# 2          50
# 3          70
# 4         121
#          ...
# 15715     143
# 15716     139
# 15717     139
# 15718       0
# 15719       0
# Name: Runs_From_Running Score, Length: 15720, dtype: object

# %%
df['Wickets_From_Running Score']=df['Wickets_From_Running Score'].astype(int)
df['Runs_From_Running Score']=df['Runs_From_Running Score'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15720 entries, 0 to 15719
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Season                      15720 non-null  int32
#  1   Match_id                    15720 non-null  int64
#  2   Innings_id                  15720 non-null  int64
#  3   Runs                        15720 non-null  int32
#  4   Balls_faced                 15720 non-null  int32
#  5   Minutes                     15720 non-null  int32
#  6   Fours                       15720 non-null  int32
#  7   Sixes                       15720 non-null  int32
#  8   Strike_rate                 15720 non-null  int32
#  9   Captain                     15720 non-null  bool
#  10  Is_not_out                  15720 non-null  bool
#  11  Running_over                15720 non-null  int32
#  12  Wickets_From_Running Score  15720 non-null  int32
# ...

# %% [markdown]
# # dataset cleaned

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(20, 6))
sns.barplot(data=df, x="Season", y="Runs", hue="Innings_id")
plt.show()

# %%
plt.figure(figsize=(20, 6))
sns.barplot(data=df, x="Season", y="Sixes", estimator=np.mean, errorbar=None)
plt.show()

# %%
plt.figure(figsize=(20, 6))
sns.pairplot(df[['Match_id','Innings_id','Runs']])
plt.show()

# %%
plt.figure(figsize=(20, 6))
sns.pairplot(df[['Balls_faced','Minutes','Fours']])
plt.show()

# %%
plt.figure(figsize=(20, 6))
sns.pairplot(df[['Sixes','Strike_rate','Wickets_From_Running Score']])
plt.show()
# Out:
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
plt.figure(figsize=(20, 6))
sns.pairplot(df[['Is_not_out','Running_over','Captain','Runs_From_Running Score']])
plt.show()
# Out:
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
